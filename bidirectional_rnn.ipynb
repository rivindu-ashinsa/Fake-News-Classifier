# %% [markdown]
# # Bidirectional LSTM Model Training

# %% [markdown]
# ## Import necessory libraries

# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
import pandas as pd
import numpy as np 
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer

# %% [markdown]
# ## Load the dataset
# (This is a sample dataset I made)

# %%
df = pd.read_csv("fake_news_sample_50.csv")

# %%
df.head()
# Out:
#    id                                              title         author  \
# 0   1          Stock Market Rises Amid Economic Recovery   Daniel White
# 1   2     Apple Plans to Implant Chips in Humans by 2030    Chris Evans
# 2   3  Scientists Develop AI That Detects Diseases Early  Michael Brown
# 3   4                    Aliens Found Living on the Moon    Emily Davis
# 4   5    Man Time Travels to 2500 and Returns With Proof    Emily Davis
#
#                                                 text  label
# 0  The initiative aims to improve citizens' well-...      0
# 1  Reports say the next generation of humans will...      1
# 2  The biodegradable alternative is expected to r...      0
# 3  Strange energy readings have been detected com...      1
# 4  Rumors suggest Musk intends to conduct secret ...      1

# %%
df.isna().sum()
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# 0    27
# 1    23
# Name: count, dtype: int64

# %%
messages = df.copy()

# %% [markdown]
# ## Cleaning texts

# %%
corpus = []
stemmer = PorterStemmer()
for i in range(0, len(messages)):
    review = re.sub("[^a-zA-Z]", " ", messages['title'][i])
    review = review.lower()
    review = review.split()   
    review = [stemmer.stem(word) for word in review if word not in stopwords.words("English")]
    review = " ".join(review)
    corpus.append(review)
corpus
# Out:
# ['stock market rise amid econom recoveri',
#  'appl plan implant chip human',
#  'scientist develop ai detect diseas earli',
#  'alien found live moon',
#  'man time travel return proof',
#  'scientist develop ai detect diseas earli',
#  'local startup win intern innov award',
#  'tech giant join hand fight climat chang',
#  'elon musk buy moon privat experi',
#  'tech giant join hand fight climat chang',
#  'alien found live moon',
#  'ancient pyramid emit mysteri energi beam',
#  'stock market rise amid econom recoveri',
#  'stock market rise amid econom recoveri',
#  'nasa discov new earth like planet',
#  'ancient pyramid emit mysteri energi beam',
#  'govern launch free healthcar plan',
#  'alien found live moon',
#  'nasa discov new earth like planet',
#  'alien found live moon',
#  'alien found live moon',
#  'scientist confirm earth flat',
#  'appl plan implant chip human',
#  'stock market rise amid econom recoveri',
#  'cure cancer hidden big pharma',
#  'stock market rise amid econom recoveri',
#  'local startup win intern innov award',
#  'nasa discov new earth like planet',
#  'man time travel return proof',
#  'nasa discov new earth like planet',
#  'new pill make live forev',
#  'ancient pyramid emit mysteri energi beam',
#  'local startup win intern innov award',
#  'declar end global health emerg',
#  'scientist confirm earth flat',
#  'secret devic allow peopl read mind',
#  'scientist confirm earth flat',
#  'secret devic allow peopl read mind',
#  'stock market rise amid econom recoveri',
#  'man time travel return proof',
#  'nasa discov new earth like planet',
#  'stock market rise amid econom recoveri',
#  'tech giant join hand fight climat chang',
#  'scientist confirm earth flat',
#  'elon musk announc breakthrough batteri technolog',
#  'nasa discov new earth like planet',
#  'nasa discov new earth like planet',
#  'new vaccin found effect viru',
#  'research creat biodegrad plastic altern',
#  'cure cancer hidden big pharma']

# %% [markdown]
# ## Applying one hot encoding

# %%
voc_size = 500
one_hot_repr = [one_hot(sent, voc_size) for sent in corpus]

# %% [markdown]
# ## Applying padding (to have a fixed input layer size)

# %%
sent_length = 10
embedded_docs = pad_sequences(one_hot_repr,sent_length)

# %% [markdown]
# ## Making the Model

# %%
dimensions = 10
model = Sequential()

model.add(Embedding(input_dim=voc_size, 
                    output_dim=dimensions, 
                    input_length=sent_length))
model.add(Bidirectional(LSTM(100)))
model.add(Dense(1,activation="sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.build(input_shape=(None, sent_length))

model.summary()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 10, 10)              │           5,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 200)                 │          88,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             201 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,001 (367.19 KB)
#  Trainable params: 94,001 (367.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_final = np.array(embedded_docs)
y_final = np.array(df['label'])

# %% [markdown]
# ## Train Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_final, y_final, test_size = 0.3, random_state=42)

# %% [markdown]
# ## Model training

# %%
model.fit(X_train,y_train,batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.5471e-04
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.5262e-04
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.5342e-04
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.5173e-04
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.5121e-04
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.4996e-04
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.4896e-04
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.4824e-04
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.4796e-04
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.4567e-04
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4496e-04
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.4429e-04
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.4307e-04
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4225e-04
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4149e-04
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4007e-04
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.3916e-04
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.3828e-04
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.3797e-04
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.3669e-04

# %% [markdown]
# ## Doing Predictions

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step

# %%
y_pred
# Out:
# array([[1.0678058e-04],
#        [9.9979192e-01],
#        [9.9973261e-01],
#        [1.0468773e-04],
#        [9.9984205e-01],
#        [1.2545215e-02],
#        [1.3032627e-04],
#        [1.0678058e-04],
#        [1.3032627e-04],
#        [9.9984205e-01],
#        [1.0678058e-04],
#        [9.9979192e-01],
#        [9.9982053e-01],
#        [4.7587632e-04],
#        [9.9984205e-01]], dtype=float32)

# %%
predictions = np.where(y_pred>=0.5,1,0)

# %% [markdown]
# ## Accuracy Checking

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93         7
#            1       1.00      0.88      0.93         8
#
#     accuracy                           0.93        15
#    macro avg       0.94      0.94      0.93        15
# weighted avg       0.94      0.93      0.93        15

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[7 0]
#  [1 7]]
